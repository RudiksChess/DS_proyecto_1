# %% [markdown]
# <h1><center>Proyecto 1 Data Science</center></h1>
# <h2><center>Catedrático Ing Luis Furlan</center></h2>
# <h3><center>Realizado por:</center></h3>
# <h3><center>Augusto Alonso, Rudik Rompich, David Cuellar</center></h3>
# <h3><center>Grupo #</center></h3>

# %%
import pandas as pd 
import glob 
import numpy as np 
import matplotlib.pyplot as plt

# %%
file_names = glob.glob("data_xlsx/*.xlsx")
names = []
for i in file_names:
    a= i.split("\\")[-1]
    names.append(a)

dF_list = []
for j in names:
    path = "Data/" + j
    print(path)
    df = pd.read_excel(r)
    # df = pd.read_excel("Data/" + j)
    # dF_list.append(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7acea41d59d9> in <module>
# ----> 1 file_names = glob.glob("data_xlsx/*.xlsx")
#       2 names = []
#       3 for i in file_names:
#       4     a= i.split("\\")[-1]
#       5     names.append(a)
#
# NameError: name 'glob' is not defined

# %%
pd.read_excel("data_csv/ESCUINTLA.xlsx")
# Out:
#                                  CODIGO DISTRITO DEPARTAMENTO  MUNICIPIO  \
# 0                         05-01-0001-42   05-021    ESCUINTLA  ESCUINTLA
# 1                         05-01-0002-42   05-022    ESCUINTLA  ESCUINTLA
# 2                         05-01-0003-42   05-021    ESCUINTLA  ESCUINTLA
# 3                         05-01-0004-42   05-022    ESCUINTLA  ESCUINTLA
# 4                         05-01-0005-42   05-022    ESCUINTLA  ESCUINTLA
# ...                                 ...      ...          ...        ...
# 2658                      05-14-0040-42   05-029    ESCUINTLA   SIPACATE
# 2659                      05-14-0041-46   05-029    ESCUINTLA   SIPACATE
# 2660                      05-14-0042-43   05-029    ESCUINTLA   SIPACATE
# 2661                                NaN      NaN          NaN        NaN
# 2662  2661 Establecimientos encontrados      NaN          NaN        NaN
#
#                            ESTABLECIMIENTO  \
# 0      EODP ANEXA A EOUM COLONIA EL RECREO
# 1      EODP DEL CENTRO DE BIENESTAR SOCIAL
# 2      EODP ANEXA A EOUM MURRAY D. LINCOLN
# 3                        EODP ANEXA A EOUM
# 4     EODP ANEXA A EOUM FRANCISCO ESPINOZA
# ...                                    ...
# 2658                       LICEO MONTE SUR
# 2659           COLEGIO CRISTIANO "EMANUEL"
# 2660                        LICEO MONTESUR
# 2661                                   NaN
# 2662                                   NaN
#
#                                               DIRECCION  TELEFONO  \
# 0              2A CALLE A 3-50 COLONIA EL RECREO ZONA 3  78896766
# 1     9A CALLE 0-25 ZONA 4 SALIDA A SANTA LUCIA COTZ...  78881765
# 2                               COLONIA MODELO I ZONA 2  78894898
# 3             6TA. CALLE 5-99 ZONA 3 COLONIA SEBASTOPOL  54134704
# 4                      1A AV. COLONIA EL FERROCARRILERO  55106764
# ...                                                 ...       ...
# 2658           5TA. CALLE 10-20- APARTAMENTO "A" ZONA 0  42176508
# 2659  3A CALLE Y 1A AVENIDA LOTE 6 DE COLONIA VINICI...  58266906
# 2660                   5TA CALLE APARTAMENTO "A" ZONA 0  42247721
# 2661                                                NaN       NaN
# 2662                                                NaN       NaN
#
#                              SUPERVISOR  \
# 0     LUZ DEL ROSARIO RODRIGUEZ DE LEON
# 1          JUAN ALBERTO MACHUCA ALVAREZ
# 2     LUZ DEL ROSARIO RODRIGUEZ DE LEON
# 3          JUAN ALBERTO MACHUCA ALVAREZ
# 4          JUAN ALBERTO MACHUCA ALVAREZ
# ...                                 ...
# 2658         WILMAR IVAN ORTIZ GONZALEZ
# 2659         WILMAR IVAN ORTIZ GONZALEZ
# 2660         WILMAR IVAN ORTIZ GONZALEZ
# 2661                                NaN
# 2662                                NaN
#
#                                      DIRECTOR          NIVEL   SECTOR    AREA  \
# 0           CECILIA CAROLINA CRUZ CASTELLANOS       PARVULOS  OFICIAL  URBANA
# 1                                         NaN       PARVULOS  OFICIAL  URBANA
# 2                 IRMA YOLANDA HERRARTE DUBÓN       PARVULOS  OFICIAL  URBANA
# 3                                         NaN       PARVULOS  OFICIAL  URBANA
# 4                                         NaN       PARVULOS  OFICIAL  URBANA
# ...                                       ...            ...      ...     ...
# 2658  MARÍA MARILSA LIMA FIGUEROA DE MURALLES       PARVULOS  PRIVADO  URBANA
# 2659                      BLANCA ESTELA RUANO  DIVERSIFICADO  PRIVADO  URBANA
# 2660     BLANCA ROSA HERNÁNDEZ MUÑOZ DE LÓPEZ       PRIMARIA  PRIVADO  URBANA
# 2661                                      NaN            NaN      NaN     NaN
# 2662                                      NaN            NaN      NaN     NaN
#
#        STATUS   MODALIDAD     JORNADA             PLAN DEPARTAMENTAL
# 0     ABIERTA  MONOLINGUE    MATUTINA  DIARIO(REGULAR)     ESCUINTLA
# 1     ABIERTA  MONOLINGUE    MATUTINA  DIARIO(REGULAR)     ESCUINTLA
# 2     ABIERTA  MONOLINGUE    MATUTINA  DIARIO(REGULAR)     ESCUINTLA
# 3     ABIERTA  MONOLINGUE    MATUTINA  DIARIO(REGULAR)     ESCUINTLA
# 4     ABIERTA  MONOLINGUE    MATUTINA  DIARIO(REGULAR)     ESCUINTLA
# ...       ...         ...         ...              ...           ...
# 2658  ABIERTA  MONOLINGUE    MATUTINA  DIARIO(REGULAR)     ESCUINTLA
# 2659  ABIERTA  MONOLINGUE       DOBLE    FIN DE SEMANA     ESCUINTLA
# 2660  ABIERTA  MONOLINGUE  VESPERTINA  DIARIO(REGULAR)     ESCUINTLA
# 2661      NaN         NaN         NaN              NaN           NaN
# 2662      NaN         NaN         NaN              NaN           NaN
#
# [2663 rows x 17 columns]
