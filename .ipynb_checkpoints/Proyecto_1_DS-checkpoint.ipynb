# %% [markdown]
# <h1><center>Proyecto 1 Data Science</center></h1>
# <h2><center>Catedrático Ing Luis Furlan</center></h2>
# <h3><center>Realizado por:</center></h3>
# <h3><center>Augusto Alonso, Rudik Rompich, David Cuellar</center></h3>
# <h3><center>Grupo #</center></h3>

# %%
import pandas as pd 
import glob 
import numpy as np 
import matplotlib.pyplot as plt 
import numpy as np

# %% [markdown]
# <h2><center>Departamento de Guatemala</center></h2>

# %%
datos_en_bruto = glob.glob("data_xlsx/GUATEMALA/*.xlsx")
paths = []
for i in datos_en_bruto:
    a= i.split("\\")[-1]
    paths.append(a)
    
data_frames_separados_guatemala = []
for j in paths:
    df = pd.read_excel(j)
    data_frames_separados_guatemala.append(df)
    
guatemala_departamento = pd.concat(data_frames_separados_guatemala)
guatemala_departamento
# Out:
#                                  CODIGO DISTRITO DEPARTAMENTO  \
# 0                         01-01-0003-45   01-110    GUATEMALA
# 1                         01-01-0017-45   01-318    GUATEMALA
# 2                         01-01-0020-45   01-627    GUATEMALA
# 3                         01-01-0021-45   01-627    GUATEMALA
# 4                         01-01-1247-45   01-105    GUATEMALA
# ...                                 ...      ...          ...
# 1792                      01-17-9598-45   01-220    GUATEMALA
# 1793                      01-17-9782-45   01-204    GUATEMALA
# 1794                      01-17-9803-45   01-204    GUATEMALA
# 1795                                NaN      NaN          NaN
# 1796  1795 Establecimientos encontrados      NaN          NaN
#
#               MUNICIPIO                     ESTABLECIMIENTO  \
# 0             GUATEMALA            LICEO CIENTIFICO CUMORAH
# 1             GUATEMALA              LICEO ROMANO AMERICANO
# ...

# %%
from pandas_profiling import ProfileReport

# %%
prof = ProfileReport(guatemala_departamento)
prof
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.0.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-07-27 00:07:25.451899&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# <h2><center>Todos los departamentos</center></h2>

# %%
datos_en_bruto_globales = glob.glob("data_xlsx/*.xlsx")
paths_globales = []
for i in datos_en_bruto_globales:
    a= i.split("\\")[-1]
    paths_globales.append(a)

departamentos = []
for j in paths_globales :
    df = pd.read_excel(j)
    departamentos.append(df)
    
departamentos.append(guatemala_departamento)

# %%
dataframe_pais = pd.concat(departamentos)
dataframe_pais
# Out:
#        Unnamed: 0 Unnamed: 1    Unnamed: 2 Unnamed: 3  \
# 0          CODIGO   DISTRITO  DEPARTAMENTO  MUNICIPIO
# 1   22-01-0001-42     22-003       JUTIAPA    JUTIAPA
# 2   22-01-0002-42     22-001       JUTIAPA    JUTIAPA
# 3   22-01-0003-42     22-001       JUTIAPA    JUTIAPA
# 4   22-01-0004-42     22-001       JUTIAPA    JUTIAPA
# ..            ...        ...           ...        ...
# 57            NaN        NaN           NaN        NaN
# 58            NaN        NaN           NaN        NaN
# 59            NaN        NaN           NaN        NaN
# 60            NaN        NaN           NaN        NaN
# 61            NaN        NaN           NaN        NaN
#
#                             Unnamed: 4  \
# 0                      ESTABLECIMIENTO
# 1   EODP EUSEBIA AUCEDA VDA.DE PADILLA
# 2                                 EODP
# 3                      LICEO 'JUTIAPA'
# 4   EODP ANEXA A EOUM LORENZO MONTUFAR
# ..                                 ...
# ...

# %% [markdown]
# <h2><center>Análisis de Variables</center></h2>
